# %%
print('hello')
# Out:
# hello

# %% [markdown]
# test

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project='100-numpy-exercises')
# Out:
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY:
#   ········
# [jovian] Creating a new project "ankur07jain/100-numpy-exercises"
# [jovian] Committed successfully! https://jovian.ai/ankur07jain/100-numpy-exercises
# 'https://jovian.ai/ankur07jain/100-numpy-exercises'
